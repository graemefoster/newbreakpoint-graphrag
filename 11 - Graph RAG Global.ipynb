# %% [markdown]
# ### Example Output of Graph RAG - Global Query
#
# python -m graphrag.query \
# --root ./ \
# --method global \
# "What paintings did Leonardo make?"
#
#
# creating llm client with {'api_key': 'REDACTED,len=32', 'type': "azure_openai_chat", 'model': 'gpt-4o', 'max_tokens': 4000, 'temperature': 0.0, 'top_p': 1.0, 'n': 1, 'request_timeout': 180.0, 'api_base': 'https://aoai.openai.azure.com/', 'api_version': '2024-04-01-preview', 'organization': None, 'proxy': None, 'cognitive_services_endpoint': None, 'deployment_name': 'gpt-4o', 'model_supports_json': True, 'tokens_per_minute': 0, 'requests_per_minute': 30, 'max_retries': 10, 'max_retry_wait': 10.0, 'sleep_on_rate_limit_recommendation': True, 'concurrent_requests': 1}
#
# SUCCESS: Global Search Response:
# ### Leonardo da Vinci's Paintings
#
# Leonardo da Vinci, one of the most renowned artists of the Renaissance, created numerous masterpieces that have left an indelible mark on the history of art. Below is a summary of some of his most significant works:
#
# #### The Last Supper
# Leonardo da Vinci painted 'The Last Supper' between 1496 and 1498 under the patronage of Ludovico Sforza. This iconic mural is located in the Refectory of the Dominican Convent of S. Maria delle Grazie in Milan. It is celebrated for its composition and the emotional depth of the figures [Data: Reports (20, 18, 15, 39, 25, 14, 38, 41, 4)].
#
# #### Mona Lisa
# The 'Mona Lisa,' also known as La Gioconda, is perhaps Leonardo's most famous painting. Housed in the Louvre Museum in Paris, it is renowned for its use of sfumato and the lifelike quality of the subject's expression [Data: Reports (20, 35, 2, 24)].
#
# #### Madonna, the Infant Christ, and Saint Anne
# This significant artwork, also known as 'The Virgin and Child with St. Anne,' is located in the Louvre. It showcases Leonardo's skill in depicting complex human emotions and interactions [Data: Reports (35, 36)].
#
# #### Virgin of the Rocks
# Leonardo created two versions of 'Virgin of the Rocks.' One is housed in the Louvre, and the other is in the National Gallery in London. Both versions highlight his mastery of chiaroscuro and sfumato techniques [Data: Reports (35, 33, 46, 45, 41)].
#
# #### The Annunciation
# Leonardo's 'The Annunciation' is housed in the Uffizi Gallery, with another version attributed to him located in the Louvre. This painting is notable for its detailed depiction of the angel Gabriel and the Virgin Mary [Data: Reports (1)].
#
# #### Baptism of Christ
# Leonardo contributed to the painting 'Baptism of Christ' by Verrocchio, specifically painting one of the attendant angels. This collaboration is an early example of his emerging talent [Data: Reports (25)].
#
# #### St. Jerome in the Desert
# An early and unfinished work by Leonardo, 'St. Jerome in the Desert,' is now housed in the Vatican. It reflects his deep interest in human anatomy and expression [Data: Reports (7)].
#
# #### Adoration of the Magi
# Another unfinished masterpiece, 'Adoration of the Magi,' is currently housed in the Uffizi Gallery. This work demonstrates Leonardo's innovative approach to composition and perspective [Data: Reports (21)].
#
# #### Lady with a Weasel
# Also known as 'Lady with an Ermine,' this painting is part of the Czartoryski Collection in Cracow. It is believed to depict Cecilia Gallerani and showcases Leonardo's skill in portraiture [Data: Reports (41, 17)].
#
# #### The Battle of Anghiari
# Although the original mural 'The Battle of Anghiari' was never completed, it is known through copies and studies. This work was commissioned by the Signoria and reflects Leonardo's interest in dynamic movement and conflict [Data: Reports (3)].
#
# #### The Virgin and Child with St. Anne and St. John
# This painting, currently housed at Burlington House, is another example of Leonardo's ability to convey complex emotional narratives through his art [Data: Reports (37)].
#
# #### Presumed Portrait of Lucrezia Crivelli
# This portrait, housed in the Louvre, reflects Leonardo's influence on his followers and his skill in capturing the subtleties of human expression [Data: Reports (35)].
#
# ### Conclusion
# Leonardo da Vinci's body of work is vast and varied, showcasing his unparalleled skill in painting, his innovative techniques, and his deep understanding of human anatomy and emotion. His masterpieces continue to be celebrated and studied for their artistic and historical significance.
